# %%
import pandas
import pylab
from pandas import *
from pylab import *

# %%
details=read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/customers/customers.csv')

# %%
details
# Out:
#       First        Last                     Email Gender  Last IP Address  \
# 0        Al      Fresco        afresco@dayrep.com      M    74.111.18.161
# 1      Abby        Kuss           akuss@rhyta.com      F    23.80.125.101
# 2     Arial       Photo         aphoto@dayrep.com      F       24.0.14.56
# 3     Bette       Alott          balott@rhyta.com      F   56.216.127.219
# 4     Barb       Barion     bbarion@superrito.com      F     38.68.15.223
# 5     Barry  DeHatchett    bdehatchett@dayrep.com      M    23.192.215.78
# 6      Bill     Melator       bmelator@einrot.com      M     24.11.125.10
# 7     Candi       Cayne          ccayne@rhyta.com      F      24.39.14.15
# 8     Carol        Ling       cling@superrito.com      F    23.180.242.66
# 9       Cam         Rha           crha@einrot.com      M      24.1.25.140
# 10      Dan     Delyons       ddelyons@dayrep.com      M    24.38.224.161
# 11     Erin     Detyers       edetyers@dayrep.com      F     70.209.14.54
# ...

# %%
details['First']
# Out:
# 0          Al
# 1        Abby
# 2       Arial
# 3       Bette
# 4       Barb
# 5       Barry
# 6        Bill
# 7       Candi
# 8       Carol
# 9         Cam
# 10        Dan
# 11       Erin
# 12      Euron
# 13     Justin
# 14       Jean
# 15        Lee
# 16       Lisa
# 17       Mary
# 18       Mike
# 19       Oren
# 20       Phil
# 21      Rowan
# 22        Ray
# 23       Sara
# 24        Sal
# 25    Seymour
# 26         Ty
# 27      Tally
# 28        Tim
# 29     Victor
# Name: First, dtype: object

# %%
details.columns
# Out:
# Index([u'First', u'Last', u'Email', u'Gender', u'Last IP Address', u'City',
#        u'State', u'Total Orders', u'Total Purchased', u'Months Customer'],
#       dtype='object')

# %%
details=read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/customers/customers.csv')
details.head()
details.tail()
# Out:
#       First   Last                 Email Gender Last IP Address       City  \
# 25  Seymour  Ofewe     sofewe@dayrep.com      M     98.29.25.44  Cleveland
# 26       Ty  Anott      tanott@rhyta.com      M     23.230.12.5   San Jose
# 27    Tally  Itupp  titupp@superrito.com      F   24.38.114.105  Sea Cliff
# 28      Tim   Pani   tpani@superrito.com      M   23.84.132.226    Buffalo
# 29   Victor   Rhee      vrhee@einrot.com      M  23.112.232.160  Green Bay
#
#    State  Total Orders  Total Purchased  Months Customer
# 25    OH             9             1190                3
# 26    CA             1               50                3
# 27    NY            11              380               42
# 28    NY             0                0                1
# 29    WI             0                0                2

# %%
#slicing by rows/ by index

# %%
details[3:7]
# Out:
#    First        Last                   Email Gender Last IP Address     City  \
# 3  Bette       Alott        balott@rhyta.com      F  56.216.127.219  Raleigh
# 4  Barb       Barion   bbarion@superrito.com      F    38.68.15.223   Dallas
# 5  Barry  DeHatchett  bdehatchett@dayrep.com      M   23.192.215.78   Boston
# 6   Bill     Melator     bmelator@einrot.com      M    24.11.125.10     Orem
#
#   State  Total Orders  Total Purchased  Months Customer
# 3    NC             6              560               18
# 4    TX             4             1590                1
# 5    MA             1               15                6
# 6    UT             9             6090               35

# %%
details['First']
# Out:
# 0          Al
# 1        Abby
# 2       Arial
# 3       Bette
# 4       Barb
# 5       Barry
# 6        Bill
# 7       Candi
# 8       Carol
# 9         Cam
# 10        Dan
# 11       Erin
# 12      Euron
# 13     Justin
# 14       Jean
# 15        Lee
# 16       Lisa
# 17       Mary
# 18       Mike
# 19       Oren
# 20       Phil
# 21      Rowan
# 22        Ray
# 23       Sara
# 24        Sal
# 25    Seymour
# 26         Ty
# 27      Tally
# 28        Tim
# 29     Victor
# Name: First, dtype: object

# %%
details[['First']]
# Out:
#       First
# 0        Al
# 1      Abby
# 2     Arial
# 3     Bette
# 4     Barb
# 5     Barry
# 6      Bill
# 7     Candi
# 8     Carol
# 9       Cam
# 10      Dan
# 11     Erin
# 12    Euron
# 13   Justin
# 14     Jean
# 15      Lee
# 16     Lisa
# 17     Mary
# 18     Mike
# 19     Oren
# 20     Phil
# 21    Rowan
# 22      Ray
# 23     Sara
# 24      Sal
# 25  Seymour
# 26       Ty
# 27    Tally
# 28      Tim
# 29   Victor

# %%
#slicing by rows and columns

details.ix[2:4, ['Email','Gender']]
# Out:
# C:\Users\apoor\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
#                    Email Gender
# 2      aphoto@dayrep.com      F
# 3       balott@rhyta.com      F
# 4  bbarion@superrito.com      F

# %%
#creating separate datasets
female_details=details[details['Gender']=='F']
female_details
# Out:
#     First        Last                   Email Gender Last IP Address  \
# 1    Abby        Kuss         akuss@rhyta.com      F   23.80.125.101
# 2   Arial       Photo       aphoto@dayrep.com      F      24.0.14.56
# 3   Bette       Alott        balott@rhyta.com      F  56.216.127.219
# 4   Barb       Barion   bbarion@superrito.com      F    38.68.15.223
# 7   Candi       Cayne        ccayne@rhyta.com      F     24.39.14.15
# 8   Carol        Ling     cling@superrito.com      F   23.180.242.66
# 11   Erin     Detyers     edetyers@dayrep.com      F    70.209.14.54
# 14   Jean       Poole       jpoole@dayrep.com      F    23.182.25.40
# 15    Lee    Hvmeehom    lhvmeehom@einrot.com      F     215.82.23.2
# 16   Lisa  Karfurless  lkarfurless@dayrep.com      F   172.189.252.8
# 17   Mary     Melator      mmelator@rhyta.com      F      23.88.15.5
# 23   Sara      Bellum   sbellum@superrito.com      F    74.111.6.173
# 27  Tally       Itupp    titupp@superrito.com      F   24.38.114.105
#
# ...

# %%
male_details=details[details['Gender']=='M']

# %%
names=details.ix[0:,['First','Last']]
names=names.set_index(['First'])
names
# Out:
#                Last
# First
# Al           Fresco
# Abby           Kuss
# Arial         Photo
# Bette         Alott
# Barb         Barion
# Barry    DeHatchett
# Bill        Melator
# Candi         Cayne
# Carol          Ling
# Cam             Rha
# Dan         Delyons
# Erin        Detyers
# Euron     Tasomthin
# Justin         Case
# Jean          Poole
# Lee        Hvmeehom
# Lisa     Karfurless
# Mary        Melator
# Mike         Rofone
# Oren        Jouglad
# Phil          Meaup
# Rowan        Deboat
# Ray         Ovlight
# Sara         Bellum
# Sal            Ladd
# Seymour       Ofewe
# Ty            Anott
# Tally         Itupp
# Tim            Pani
# Victor         Rhee

# %%
import pandas as pd

# this turns off warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
{'grades':[50,90,100,80,70]}
# Out:
# {'grades': [50, 90, 100, 80, 70]}

# %%
{ {'names':['b','c','d','e','a']} { 'grades':[50,90,100,80,70]}}
# Out:
#   File "<ipython-input-24-d17148e0df83>", line 1
#     { {'names':['b','c','d','e','a']} { 'grades':[50,90,100,80,70]}}
#                                       ^
# SyntaxError: invalid syntax

# %%
#construct your dataset with your own data
grades = pd.Series(data = [100,80,100,90,80,70], name = "Grades", dtype='int')
grades
# Out:
# 0    100
# 1     80
# 2    100
# 3     90
# 4     80
# 5     70
# Name: Grades, dtype: int32

# %%
print("Highest grade:", grades.max())
print("Average grade:", grades.mean())
print("lowest grade:", grades.min())
print("Sum of grades:", grades.sum())
print("Count of grades", grades.count())
# Out:
# ('Highest grade:', 100)
# ('Average grade:', 86.66666666666667)
# ('lowest grade:', 70)
# ('Sum of grades:', 520)
# ('Count of grades', 6)

# %%
dir(grades)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
#creating a dataframe using pandas series datasets by using dictionaries
gpa=pd.Series(data=[100,70,80,60,80,40])
names=pd.Series(data=['Apoo','James','Kim','Jake','Ben'])
years=pd.Series(data=['sr','jr','so','gr','fr'])

gpa_dict={'Names':names,'Years':years,'GPA':gpa}
GPA_DF=pd.DataFrame(gpa_dict)
GPA_DF
# Out:
#    GPA  Names Years
# 0  100   Apoo    sr
# 1   70  James    jr
# 2   80    Kim    so
# 3   60   Jake    gr
# 4   80    Ben    fr
# 5   40    NaN   NaN

# %%
GPA_DF['Names']
# Out:
# 0     Apoo
# 1    James
# 2      Kim
# 3     Jake
# 4      Ben
# 5      NaN
# Name: Names, dtype: object

# %%
GPA_DF[['Names']]
# Out:
#    Names
# 0   Apoo
# 1  James
# 2    Kim
# 3   Jake
# 4    Ben
# 5    NaN

# %%
#ORDERING COLUMN NAMES
students = pd.DataFrame( gpa_dict, columns = ['Names', 'GPA', 'Years'] )
students
# Out:
#    Names  GPA Years
# 0   Apoo  100    sr
# 1  James   70    jr
# 2    Kim   80    so
# 3   Jake   60    gr
# 4    Ben   80    fr
# 5    NaN   40   NaN

# %%
for column in students:
    print column
# Out:
# Names
# GPA
# Years

# %%
#for values?
#use to_records()
for column in students:
    print column
# Out:
# Names
# GPA
# Years

# %%
for cval in students.to_records():
    print cval
# Out:
# (0L, 'Apoo', 100L, 'sr')
# (1L, 'James', 70L, 'jr')
# (2L, 'Kim', 80L, 'so')
# (3L, 'Jake', 60L, 'gr')
# (4L, 'Ben', 80L, 'fr')
# (5L, nan, 40L, nan)

# %%
for cval in students.to_records():
    if cval['GPA']>=80:
        print cval['Names'],cval['Years']
# Out:
# Apoo sr
# Kim so
# Ben fr

# %%
students.head()
# Out:
#    Names  GPA Years
# 0   Apoo  100    sr
# 1  James   70    jr
# 2    Kim   80    so
# 3   Jake   60    gr
# 4    Ben   80    fr

# %%
deanlist=students[['Names','GPA']][students.GPA>=80]
deanlist
# Out:
#   Names  GPA
# 0  Apoo  100
# 2   Kim   80
# 4   Ben   80

# %%
#tell them the difference between series and DFs

# %%
students['GPA']#series
# Out:
# 0    100
# 1     70
# 2     80
# 3     60
# 4     80
# 5     40
# Name: GPA, dtype: int64

# %%
students[['GPA']]
# Out:
#    GPA
# 0  100
# 1   70
# 2   80
# 3   60
# 4   80
# 5   40

# %%
students[['Names','Years']]
# Out:
#    Names Years
# 0   Apoo    sr
# 1  James    jr
# 2    Kim    so
# 3   Jake    gr
# 4    Ben    fr
# 5    NaN   NaN

# %%
#selecting rows in a dataframe

students.head(2)
# Out:
#    Names  GPA Years
# 0   Apoo  100    sr
# 1  James   70    jr

# %%
students.tail(2)
# Out:
#   Names  GPA Years
# 4   Ben   80    fr
# 5   NaN   40   NaN

# %%
students.sample(2)
# Out:
#   Names  GPA Years
# 3  Jake   60    gr
# 2   Kim   80    so

# %%
#boolean indexing
students['Years'] == 'Fr'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Years, dtype: bool

# %%
students[students['Years']=='gr']
# Out:
#   Names  GPA Years
# 3  Jake   60    gr

# %%
students[ (students.GPA >=40)&(|.GPA< 80)]
# Out:
#    Names  GPA Years
# 1  James   70    jr
# 2    Kim   80    so
# 3   Jake   60    gr
# 4    Ben   80    fr
# 5    NaN   40   NaN

# %%
##########building interactions##############333

# %%
customers = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/customers/customers.csv')

customer_list = customers.sample(5)

# %%
print("CUSTOMER INQUIRY")
display(customer_list[['Email']])
email = raw_input("Enter a customer email to retrieve their complete record: ".lower())

print("CUSTOMER DETAILS FOR " + email )
display(customer_list[ customer_list['Email'] == email])
# Out:
# CUSTOMER INQUIRY
#                      Email
# 29        vrhee@einrot.com
# 2        aphoto@dayrep.com
# 6      bmelator@einrot.com
# 28     tpani@superrito.com
# 16  lkarfurless@dayrep.com
# enter a customer email to retrieve their complete record: vrhee@einrot.com
# CUSTOMER DETAILS FOR vrhee@einrot.com
#      First  Last             Email Gender Last IP Address       City State  \
# 29  Victor  Rhee  vrhee@einrot.com      M  23.112.232.160  Green Bay    WI
#
#     Total Orders  Total Purchased  Months Customer
# 29             0                0                2

# %%
import pandas as pd

customers = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/customers/customers.csv')
customers.head()
# Out:
#    First    Last                  Email Gender Last IP Address      City  \
# 0     Al  Fresco     afresco@dayrep.com      M   74.111.18.161  Syracuse
# 1   Abby    Kuss        akuss@rhyta.com      F   23.80.125.101   Phoenix
# 2  Arial   Photo      aphoto@dayrep.com      F      24.0.14.56    Newark
# 3  Bette   Alott       balott@rhyta.com      F  56.216.127.219   Raleigh
# 4  Barb   Barion  bbarion@superrito.com      F    38.68.15.223    Dallas
#
#   State  Total Orders  Total Purchased  Months Customer
# 0    NY             1               45                1
# 1    AZ             1               25                2
# 2    NJ             1              680                1
# 3    NC             6              560               18
# 4    TX             4             1590                1

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1], [np.nan, np.nan, np.nan, 5]], columns=list('ABCD'))
df
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df.dropna(axis=1, how='all') #when all values in a column are na values u drop na
# Out:
#      A    B  D
# 0  NaN  2.0  0
# 1  3.0  4.0  1
# 2  NaN  NaN  5

# %%
df.dropna(axis=1, how='any')#even if one value is a column is na drop it
# Out:
#    D
# 0  0
# 1  1
# 2  5

# %%
df.dropna(axis=0, how='all')#if all values are na in a row drop it
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df.dropna(axis=1, how='all')
df.dropna(axis=1, how='any')
df.dropna(axis=0, how='all')

# %%
students_list_of_dict = [
    { 'Name' : 'Bob', 'GPA' : 3.0 },
    { 'Name' : 'Sue', 'GPA' : 3.7 },
    { 'Name' : 'Tom', 'GPA' : 2.4 }
]

students_df = pd.DataFrame(students_list_of_dict)
students_df
# Out:
#    GPA Name
# 0  3.0  Bob
# 1  3.7  Sue
# 2  2.4  Tom

# %%
import pandas as pd
json_data = '[{"GPA":3.0,"Name":"Bob"},{"GPA":3.7,"Name":"Sue"},{"GPA":2.4,"Name":"Tom"}]'
json_data
#tweets = pd.read_json(json_data, orient='records')
#tweets.head()
# Out:
# '[{"GPA":3.0,"Name":"Bob"},{"GPA":3.7,"Name":"Sue"},{"GPA":2.4,"Name":"Tom"}]'
